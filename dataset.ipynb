# %%
Introduction To Datatypes
i = 10
type(i)
int
print(type(i))
<class 'int'>
i
10
print(i)
10
 
Strings
Strings - a collection of characters
Can be defined using either double quotes or single quotes
IMMUTABLE
s = "WELCOME"
a = 'Jupyter Notebook'
# Hash is used to specify the comments
# len - is the function to get the length of any container
len(s)
7
type(s)
str
print(type(s))
<class 'str'>
Indexing
Positive Indexing
# The index starts from 0 (Zero) to length-1 
# To access any element, always use subscript operator []
s[0]
'W'
s[6]
'E'
s[7]
---------------------------------------------------------------------------
IndexError                                Traceback (most recent call last)
<ipython-input-15-b035325af127> in <module>
----> 1 s[7]

IndexError: string index out of range
Negative Indexing
s[-1]
'E'
s[-7]
'W'
s[-8]
---------------------------------------------------------------------------
IndexError                                Traceback (most recent call last)
<ipython-input-18-28d43f500622> in <module>
----> 1 s[-8]

IndexError: string index out of range
 
Slicing
Extracts a substring from a string
Syntax: StartPos : EndPos : SkipCount/Direction
StartPos -> Included, EndPos -> Excluded
By default, slicing always works from left to right (unless changed by direction)
s[0:3]
'WEL'
s[3:7]
'COME'
s[:3]
'WEL'
s[3:]
'COME'
s[3:100]
'COME'
 
# Negative indexing can also be used with slicing
s[-7:-4]
'WEL'
s[-1:-4]
''
s[-7:3]
'WEL'
s[-100:3]
'WEL'
s[:]
'WELCOME'
s[]
  File "<ipython-input-30-d5d19ff545f3>", line 1
    s[]
      ^
SyntaxError: invalid syntax
s[::2]
'WLOE'
s[::3]
'WCE'
s[::-1]
'EMOCLEW'
s[::-2]
'EOLW'
 
Excercise: Write a program to extract 'Class' from the below string
msg = "Welcome to Python Programming Class"

msg = "Welcome to Python Programming Class"
msg[-5:]
'Class'
msg[30:36]
'Class'
msg[-5:-1]
'Clas'
 
s
'WELCOME'
s + 10
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
<ipython-input-40-30fc4c06cb2b> in <module>
----> 1 s + 10

TypeError: can only concatenate str (not "int") to str
s + "10"
'WELCOME10'
s
'WELCOME'
a = s + "10"
s
'WELCOME'
a
'WELCOME10'
10 + 4.5
14.5
s * 3
'WELCOMEWELCOMEWELCOME'
# * => Can work either as a multiplication operator or repetition operator
type(a)
str
 
Lists
Ordered Collection of items/elements/objects
Syntax: [ ]
MUTABLE
languages = ["C", "Cpp", 'Java', "C#"]
print(type(languages))
<class 'list'>
len(languages)
4
languages
['C', 'Cpp', 'Java', 'C#']
languages[0]
'C'
languages[-1]
'C#'
languages[2]
'Java'
languages[-1]
'C#'
languages[-1][-1]
'#'
languages
['C', 'Cpp', 'Java', 'C#']
languages[0:2]
['C', 'Cpp']
languages + 10
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
<ipython-input-61-cd258c513c2d> in <module>
----> 1 languages + 10

TypeError: can only concatenate list (not "int") to list
languages + [123]
['C', 'Cpp', 'Java', 'C#', 123]
languages * 3
['C', 'Cpp', 'Java', 'C#', 'C', 'Cpp', 'Java', 'C#', 'C', 'Cpp', 'Java', 'C#']
languages
['C', 'Cpp', 'Java', 'C#']
languages
['C', 'Cpp', 'Java', 'C#']
languages[-1]
'C#'
a = languages[-1]
a
'C#'
a[1]
'#'
a[-1]
'#'
languages[-1][1]
'#'
Append
Always adds an element/object at the end of the list
languages.append("Python")
languages
['C', 'Cpp', 'Java', 'C#', 'Python']
Insert
Inserts an element/object at a specified index
languages.insert(2, "Ruby")
languages
['C', 'Cpp', 'Ruby', 'Java', 'C#', 'Python']
languages.insert(0, "Pascal")
languages
['Pascal', 'C', 'Cpp', 'Ruby', 'Java', 'C#', 'Python']
# Add an element after C# , "Scala" using -ve index
help(list.insert)
Help on method_descriptor:

insert(self, index, object, /)
    Insert object before index.

languages.insert(-1, "Scala")
languages
['Pascal', 'C', 'Cpp', 'Ruby', 'Java', 'C#', 'Scala', 'Python']
languages.insert(-2, "Golang")
languages
['Pascal', 'C', 'Cpp', 'Ruby', 'Java', 'C#', 'Golang', 'Scala', 'Python']
languages
['Pascal', 'C', 'Cpp', 'Ruby', 'Java', 'C#', 'Golang', 'Scala', 'Python']
 
Remove
Remove an element/object based on value
help(list.remove)
Help on method_descriptor:

remove(self, value, /)
    Remove first occurrence of value.
    
    Raises ValueError if the value is not present.

languages
['Pascal', 'C', 'Cpp', 'Ruby', 'Java', 'C#', 'Golang', 'Scala', 'Python']
languages.remove("Ruby")
languages
['Pascal', 'C', 'Cpp', 'Java', 'C#', 'Golang', 'Scala', 'Python']
languages.remove("java")
---------------------------------------------------------------------------
ValueError                                Traceback (most recent call last)
<ipython-input-92-9dec42f52c0c> in <module>
----> 1 languages.remove("java")

ValueError: list.remove(x): x not in list
Pop
Remove an element/object based on index, by default the index is -1
languages
['Pascal', 'C', 'Cpp', 'Java', 'C#', 'Golang', 'Scala', 'Python']
languages.pop(2)
'Cpp'
languages
['Pascal', 'C', 'Java', 'C#', 'Golang', 'Scala', 'Python']
languages.pop()
'Python'
languages
['Pascal', 'C', 'Java', 'C#', 'Golang', 'Scala']
help(list.pop)
Help on method_descriptor:

pop(self, index=-1, /)
    Remove and return item at index (default last).
    
    Raises IndexError if list is empty or index is out of range.

languages
['Pascal', 'C', 'Java', 'C#', 'Golang', 'Scala']
Delete
Using del keyword
languages
['Pascal', 'C', 'Java', 'C#', 'Golang', 'Scala']
del languages[2]
languages
['Pascal', 'C', 'C#', 'Golang', 'Scala']
# Use tab, shift+tab combination(s) to get the auto-completion and help on any operation
languages
['Pascal', 'C', 'C#', 'Golang', 'Scala']
del languages[0:2]
languages
['C#', 'Golang', 'Scala']
 
languages
['C#', 'Golang', 'Scala']
languages[1][0:2]
'Go'
# languages = ['C#', 'Golang', 'Scala']
numlist = [100, 200, 300]
languages.append(numlist)
languages
['C#', 'Golang', 'Scala', [100, 200, 300]]
len(languages)
4
languages[-1]
[100, 200, 300]
languages[-1][-1]
300
s
'WELCOME'
languages.append(s)
languages
['C#', 'Golang', 'Scala', [100, 200, 300], 'WELCOME']
Extend
Extends the list with the elements of the container/object passed
Increases the length of list by the len of the object/element passed
languages
['C#', 'Golang', 'Scala', [100, 200, 300], 'WELCOME']
numlist
[100, 200, 300]
s
'WELCOME'
languages.extend(numlist)
languages
['C#', 'Golang', 'Scala', [100, 200, 300], 'WELCOME', 100, 200, 300]
len(languages)
8
languages.extend(s)
languages
['C#',
 'Golang',
 'Scala',
 [100, 200, 300],
 'WELCOME',
 100,
 200,
 300,
 'W',
 'E',
 'L',
 'C',
 'O',
 'M',
 'E']
len(languages)
15
 
Count
languages
['C#',
 'Golang',
 'Scala',
 [100, 200, 300],
 'WELCOME',
 100,
 200,
 300,
 'W',
 'E',
 'L',
 'C',
 'O',
 'M',
 'E']
languages.count("E")
2
languages.count("e")
0
languages.count(100)
1
languages.index(300)
7
 
languages
['C#',
 'Golang',
 'Scala',
 [100, 200, 300],
 'WELCOME',
 100,
 200,
 300,
 'W',
 'E',
 'L',
 'C',
 'O',
 'M',
 'E']
languages[0]
'C#'
languages[0] = "C-Sharp"
languages
['C-Sharp',
 'Golang',
 'Scala',
 [100, 200, 300],
 'WELCOME',
 100,
 200,
 300,
 'W',
 'E',
 'L',
 'C',
 'O',
 'M',
 'E']
s
'WELCOME'
s[0] = 'Z'
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
<ipython-input-138-af1f7896462d> in <module>
----> 1 s[0] = 'Z'

TypeError: 'str' object does not support item assignment
s = "ZELCOME"
s
'ZELCOME'
s[-1] = 'E'
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
<ipython-input-141-515ed07c0ef8> in <module>
----> 1 s[-1] = 'E'

TypeError: 'str' object does not support item assignment
# IMMUTABLE VS MUTABLE
# Strings -> IMMUTABLE
# LISTS   -> MUTABLE
s
'ZELCOME'
s.replace("Z", "W")
'WELCOME'
s
'ZELCOME'
 
s = "WELCOME"
id(s)
1791074376880
s = "ZELCOME"
id(s)
1791112273712
s
'ZELCOME'
id(s.replace("Z", "D"))
1791112273840
s
'ZELCOME'
# Reference Counting Mechanism
a = "July"
id(a)
1791071517872
b = "July"
id(b)
1791071517872
a = "Jul"
id(a)
1791049029552
a = "June"
id(a)
1791071517744
 
languages
['C-Sharp',
 'Golang',
 'Scala',
 [100, 200, 300],
 'WELCOME',
 100,
 200,
 300,
 'W',
 'E',
 'L',
 'C',
 'O',
 'M',
 'E']
languages = ["C", "Ruby", "Perl", "Python", "Java"]
Sort
languages.sort()
languages
['C', 'Java', 'Perl', 'Python', 'Ruby']
languages.sort(reverse=True)
languages
['C', 'Ruby', 'Perl', 'Python', 'Java']
Reverse
languages.reverse()
languages
['C', 'Java', 'Perl', 'Python', 'Ruby']
 
 
Tuples
Ordered Collection of items/objects/elements
Syntax: ( )
IMMUTABLE
vaccines = ("Covaxin", "Covishield", "Sputnik")
vaccines
('Covaxin', 'Covishield', 'Sputnik')
type(vaccines)
tuple
len(vaccines)
3
vaccines[0]
'Covaxin'
vaccines[-1]
'Sputnik'
vaccines[0:2]
('Covaxin', 'Covishield')
vaccines.count("Covaxin")
1
vaccines.index("Sputnik")
2
vaccines
('Covaxin', 'Covishield', 'Sputnik')
vaccines[1:2]
('Covishield',)
vaccines[0:2]
('Covaxin', 'Covishield')
 
vaccines
('Covaxin', 'Covishield', 'Sputnik')
del vaccines[0]
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
<ipython-input-186-d7cddcbfbacb> in <module>
----> 1 del vaccines[0]

TypeError: 'tuple' object doesn't support item deletion
s
'ZELCOME'
s[0] = "W"
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
<ipython-input-188-b67d8d5432fb> in <module>
----> 1 s[0] = "W"

TypeError: 'str' object does not support item assignment
 
Packing
rs = "Rohit", 39, "MUM"
rs
('Rohit', 39, 'MUM')
type(rs)
tuple
 
speed = "fast"
type(speed)
str
speed = "slow",
type(speed)
tuple
 
IN keyword
Checks if element exists in the container (List/tuple/string/dict)
vaccines
('Covaxin', 'Covishield', 'Sputnik')
"Covaxin" in vaccines
True
"Test" in vaccines
False
"Test" not in vaccines
True
languages
['C', 'Ruby', 'Perl', 'Python', 'Java']
"Ruby" in languages
True
"Golang" in languages
False
s
'ZELCOME'
"L" in s
True
"W" in s
False
"W" not in s
True
 
Mutable objects in Tuple
fruits = ("apple", "banana", [1, 2, 3], "dates")
type(fruits)
tuple
len(fruits)
4
fruits[2]
[1, 2, 3]
fruits[2].append(4)
fruits
('apple', 'banana', [1, 2, 3, 4], 'dates')
fruits[0]
'apple'
fruits[0] = "Cherry"
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
<ipython-input-214-afc59a11a144> in <module>
----> 1 fruits[0] = "Cherry"

TypeError: 'tuple' object does not support item assignment
fruits[2]
[1, 2, 3, 4]
fruits[2] = [100, 200, 300]
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
<ipython-input-216-76f7a629ee9a> in <module>
----> 1 fruits[2] = [100, 200, 300]

TypeError: 'tuple' object does not support item assignment
fruits
('apple', 'banana', [1, 2, 3, 4], 'dates')
id(fruits[2])
1791117557184
fruits[2] = "orange"
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
<ipython-input-219-e72e9316640a> in <module>
----> 1 fruits[2] = "orange"

TypeError: 'tuple' object does not support item assignment
fruits[2][0] = "One"
fruits
('apple', 'banana', ['One', 2, 3, 4], 'dates')
fruits[2].insert(1, "two")
fruits
('apple', 'banana', ['One', 'two', 2, 3, 4], 'dates')
Misc - Strings
location = "C:\newfolder"
print(location)
C:
ewfolder
location = "C:\\newfolder\\users\\training\\python\\test"
print(location)
C:\newfolder\users\training\python\test
location = r"C:\newfolder\users\training\python\test"
print(location)
C:\newfolder\users\training\python\test
# r => Refers to RAW String, treats the string as it is. Don't escape any characters
 
Format
sessionCount = 10
chapters = 8
msg = "There will be " + str(chapters) + " chapters in the course, spanned across " + str(sessionCount) + " sessions."
print(msg)
There will be 8 chapters in the course, spanned across 10 sessions.
msg = "There will be {} chapters in the course, spanned across {} sessions"
msg
'There will be {} chapters in the course, spanned across {} sessions'
msg = "There will be {} chapters in the course, spanned across {} sessions".format(chapters, sessionCount)
print(msg)
There will be 8 chapters in the course, spanned across 10 sessions
 
Dictionaries
Collection of key - value pairs
Syntax: { }
MUTABLE
Collection of {K1: V1, K2: V2, K3: V3}
Example: {RN1: N1, RN2: N2, RN3: N3}
Maps, Hash Maps
fruits = {"a": "apple", "b": "banana", "c": "cherry"}
type(fruits)
dict
len(fruits)
3
fruits['a']
'apple'
fruits["p"]
---------------------------------------------------------------------------
KeyError                                  Traceback (most recent call last)
<ipython-input-253-fbff42db7bf9> in <module>
----> 1 fruits["p"]

KeyError: 'p'
 
Add elements to dict
